# %%
#import libraries
import matplotlib.pyplot as plt
import numpy as np

# %%
##TCP
# Define lists to store the output data
txPacketsList = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000]
rx_bytes = [4500, 4500, 4500, 748500, 2248500, 3748500, 5248500, 6748500, 8248500, 9748500]
throughputList = [53.7199,234.608,367.179,382.983,378.468,381.518,383.632,383.863,380.864,381.297,382.891,384.484]
avgJitterList = [8.16e-06, 7.16e-06, 6.16e-06, 6.0e-06, 5.99e-06, 5.80e-06, 1.56e-06, 1.66e-06, 1.4e-06, 1.06e-06]
avgDelayList = [0.00350659, 0.00200962, 0.00253418, 0.00280031, 0.00329873, 0.00226792, 0.00299801, 0.00218671, 0.00317785, 0.00254673]
# Display the lists
print("Tx Packets:", txPacketsList)
print("Throughput:", throughputList)
print("Average Jitter:", avgJitterList)
print("Average Delay:", avgDelayList)
# Out:
# Tx Packets: [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000]
# Throughput: [53.7199, 234.608, 367.179, 382.983, 378.468, 381.518, 383.632, 383.863, 380.864, 381.297, 382.891, 384.484]
# Average Jitter: [8.16e-06, 7.16e-06, 6.16e-06, 6e-06, 5.99e-06, 5.8e-06, 1.56e-06, 1.66e-06, 1.4e-06, 1.06e-06]
# Average Delay: [0.00350659, 0.00200962, 0.00253418, 0.00280031, 0.00329873, 0.00226792, 0.00299801, 0.00218671, 0.00317785, 0.00254673]

# %%
##UDP
# Define the data as lists
tx_packets = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000]
rx_bytes = [4500, 4500, 4500, 748500, 2248500, 3748500, 5248500, 6748500, 8248500, 9748500]
throughput = [1205.49, 1205.49, 1205.49, 778.062, 777.584, 777.701, 777.403, 777.226, 777.056, 776.938]
average_jitter = [8.16e-06, 8.16e-06, 8.16e-06, 2.66955e-05, 1.73736e-05, 1.55082e-05, 1.47156e-05, 1.42756e-05, 1.39967e-05, 1.38037e-05]
average_delay = [0.00703341, 0.00703341, 0.00703341, 0.00323223, 0.00956698, 0.0159193, 0.0222783, 0.0286399, 0.0350045, 0.0413737]
# Print the lists to verify the data
print("Tx Packets:", tx_packets)
print("Throughput:", throughput)
print("Average Jitter:", average_jitter)
print("Average Delay:", average_delay)
# Out:
# Tx Packets: [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000]
# Throughput: [1205.49, 1205.49, 1205.49, 778.062, 777.584, 777.701, 777.403, 777.226, 777.056, 776.938]
# Average Jitter: [8.16e-06, 8.16e-06, 8.16e-06, 2.66955e-05, 1.73736e-05, 1.55082e-05, 1.47156e-05, 1.42756e-05, 1.39967e-05, 1.38037e-05]
# Average Delay: [0.00703341, 0.00703341, 0.00703341, 0.00323223, 0.00956698, 0.0159193, 0.0222783, 0.0286399, 0.0350045, 0.0413737]

# %%
# Data
avgJitterList = [8.16e-06, 8.16e-06, 8.16e-06, 2.66955e-05, 1.73736e-05, 1.55082e-05, 1.47156e-05, 1.42756e-05, 1.39967e-05, 1.38037e-05]
average_jitter = [8.16e-06, 7.16e-06, 6.16e-06, 6.0e-06, 5.99e-06, 5.80e-06, 1.56e-06, 1.66e-06, 1.4e-06, 1.06e-06]
tx_bytes = [1500000, 3000000, 4500000, 6000000, 7500000, 9000000, 10500000, 12000000, 13500000, 15000000]
# Create a list of indices to use as x-axis labels
indices = list(range(len(avgJitterList)))
# Create the bar plot
plt.bar(indices, average_jitter, width=0.4, label='average_jitter(TCP)')
plt.bar([i + 0.4 for i in indices], avgJitterList, width=0.4, label='avgJitterList(UDP)')
# Add labels and title
plt.xlabel('packets(1500000->15000000)')
plt.ylabel('Average Jitter')
plt.title('avgJitter Comparison ')
# Add x-axis labels
plt.xticks([i + 0.2 for i in indices], indices)
# Add a legend
plt.legend()
# Show the plot
plt.show()

# %%
# Given data
average_delay = [0.00703341, 0.00703341, 0.00703341, 0.00323223, 0.00956698, 0.0159193, 0.0222783, 0.0286399, 0.0350045, 0.0413737]
avgDelayList = [0.00350659, 0.00200962, 0.00253418, 0.00280031, 0.00329873, 0.00226792, 0.00299801, 0.00218671, 0.00317785, 0.00254673]
tx_bytes = [1500000, 3000000, 4500000, 6000000, 7500000, 9000000, 10500000, 12000000, 13500000, 15000000]
# Create positions for bars
positions = np.arange(len(avgDelayList))
# Plotting
plt.figure(figsize=(10, 6))
# Bar plot for avgDelayList
plt.bar(positions, avgDelayList, width=0.4, align='center', label='avgDelayList(TCP)')
# Bar plot for average_delay (offset the position to the right)
plt.bar(positions + 0.4, average_delay, width=0.4, align='center', label='average_delay(UDP)')
# Labels and titles
plt.xlabel('packets(1500000->15000000)')
plt.ylabel('Average Delay')
plt.title('Average Delay Comparison')
# Tick labels
plt.xticks(positions + 0.2, range(len(avgDelayList)))
#Show the plot
plt.legend()
plt.show()

# %%
# Data
throughputList = [53.7199, 234.608, 367.179, 382.983, 378.468, 381.518, 383.632, 383.863, 380.864, 381.297]
tx_bytes = [1500000, 3000000, 4500000, 6000000, 7500000, 9000000, 10500000, 12000000, 13500000, 15000000]
throughput = [1205.49, 1205.49, 1205.49, 778.062, 777.584, 777.701, 777.403, 777.226, 777.056, 776.938]
# Create positions for bars
positions = np.arange(len(throughputList))
# Plotting
plt.figure(figsize=(10, 6))
# Bar plot for throughputList
plt.bar(positions, throughputList, width=0.4, align='center', label='Throughput List(TCP)')
# Bar plot for throughput (offset the position to the right)
plt.bar(positions + 0.4, throughput, width=0.4, align='center', label='Throughput(UDP)')
# Labels and titles
plt.xlabel('packets(1500000->15000000)')
plt.ylabel('Throughput')
plt.title('Throughput Comparison')
# Tick labels
plt.xticks(positions + 0.2, range(len(throughputList)))
# Show the plot
plt.legend()
plt.show()
